# %%
import os
os.getcwd()
# Out:
# '/Users/charmay/Portfolio/qld_public_dental_list/notebooks'

# %% [markdown]
# ## Import CSVs

# %%
from pathlib import Path
import pandas as pd

# Current working directory (notebooks folder)
BASE_DIR = Path.cwd()

# Move up one level to project root
PROJECT_ROOT = BASE_DIR.parent

# Relative paths
PATHS = {
    'monthly' :                 PROJECT_ROOT / "data" / "processed" / "EDA" / "monthly_totals_waiting_and_treated.csv",
    'quarter_visit' :           PROJECT_ROOT / "data" / "processed" / "EDA" / "QTR_visit_totals_wt.csv",
    'avg_visit_pct' :           PROJECT_ROOT / "data" / "processed" / "EDA" / "pct_of_visit_type.csv",
    'avg_clinic_capacity' :     PROJECT_ROOT / "data" / "processed" / "EDA" / "capacity_per_clinic_catchment.csv",
}

# Descriptions
        # monthly
        # quarter_visit
        # quarter_visit_pct      -- Quarterly percentage of total waiting per type of visit
        # avg_clinic_capacity      -- total waiting and treated, per clinic & catchment
        # 

df                     = pd.read_csv(PATHS['monthly'])
df_visit_quarterly     = pd.read_csv(PATHS['quarter_visit'])
df_avg_visit_pct       = pd.read_csv(PATHS['avg_visit_pct'])
df_catchment_avg       = pd.read_csv(PATHS['avg_clinic_capacity'])

# %%
df_quarterly           = df_visit_quarterly.groupby(['quarter_start']).agg({
    'total_waiting': 'sum',
    'total_treated': 'sum'
})

# %%
df_quarterly.index = pd.to_datetime(df_quarterly.index)

# inplace=True modifies the original DataFrame directly. 
# without it I'd have to reassign: df = df.set_index('quarter_start') every time I want to use the indexed version.
# Setting the index to 'quarter_start' allows for easier time-based operations and plotting.

# %% [markdown]
# ## Quarterly Timeseries
# Trends in monthly numbers are consistant with quarterly numbers, collect the average of patients treated and waiting across months to inform their incomplete quarters. Complete missing quarters are redacted and highlighted to abide integrity.

# %%
# visualise quarterly patients treated and waiting

##Missing Months:
##                2020 --  1, 4-6, 12  - Q1 and Q4 quarter are partial. 
##                2021 --  7-12 - Q3 & Q4  
##                2022 --   1-6 - Q1 & Q2 
##                2023 --   1-3 - Q1

import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(specs=[[{"secondary_y": True}]])


# Add traces
fig.add_trace(go.Scatter(
    x=df_quarterly.index, 
    y=df_quarterly['total_waiting'],
    mode='lines',
    name='Patients Waiting',
    text=[''] * (len(df_quarterly) - 1) + ['Waited'],  # label only on last point
    textposition='middle right',
    textfont=dict(color='rgba(255, 100, 100, 0.9)', size=11),
    fill='tonexty',                         #fills to next
    fillcolor='rgba(100, 149, 237, 0.1)',  # light blue fill
    line=dict(color='rgba(100, 149, 237, 0.4)', width=1.5),
    showlegend=False,                     # ← hide from legend box
), secondary_y=False)

fig.add_trace(go.Scatter(
    x=df_quarterly.index,
    y=df_quarterly['total_treated'],
    text=[''] * (len(df_quarterly) - 1) + ['Treated'],
    textposition='middle right',
    textfont=dict(color='rgba(255, 100, 100, 0.9)', size=11),
    mode='lines',
    name='Patients Treated',
    fill='tozeroy',                        # fills down to zero
    fillcolor='rgba(37, 99, 235, 0.3)', # medium blue fill
    line=dict(color='rgba(59, 130, 246, 0.8)', width=1.5),
    showlegend=False,
), secondary_y=True)

fig.update_yaxes(
    range=[0, df['total_waiting'].max()*1.1],
    secondary_y=True
)
fig.update_yaxes(
    range=[0, df['total_waiting'].max()*1.1],
    secondary_y=False
)
# Connect the lines across missing data points, 
# so the line will continue through the shaded areas without breaks.
fig.update_traces(connectgaps=True) 

# Shade each missing monthly period

fig.add_vrect(x0='2019-09-01', x1='2019-12-31', 
              fillcolor='lightcoral', opacity=0.1, layer='below', line_width=0)
fig.add_vrect(x0='2020-04-01', x1='2020-06-30', 
              fillcolor='lightcoral', opacity=0.1, layer='below', line_width=0)
# 2021: Q3-Q4 missing
fig.add_vrect(x0='2021-07-01', x1='2021-12-31',
              fillcolor='lightcoral', opacity=0.1, layer='below', line_width=0,
              annotation_text='Missing Data',  
              annotation=dict(xref='paper', 
                              yref='paper',
                              font_size=12, 
                              font_color='salmon'))

# 2022: Q1-Q2 missing  
fig.add_vrect(x0='2022-01-01', x1='2022-06-30',
              fillcolor='lightcoral', opacity=0.1, layer='below', line_width=0)

# 2023: Q1 missing
fig.add_vrect(x0='2023-01-01', x1='2023-03-31',
              fillcolor='lightcoral', opacity=0.1, layer='below', line_width=0)
fig.add_vline(x='2023-06-01', line_width=2, line_dash="dot", line_color="slategray",)
fig.add_annotation(x=pd.to_datetime('2023-06-01'),
                   y=-0.01,  # position below x-axis
                   ay=20,  # offset in pixels
                   ax=40,  # offset in pixels
                   axref='pixel',
                   ayref='pixel',
                   yref='paper',
                   text="Quarterly Collection Starts",
                   xanchor='left',
                   yanchor='top',
                   showarrow=True)

fig.update_layout(
    legend=dict(orientation="h", yanchor="bottom", y=1, xanchor="right", x=0.92),
    margin=dict(
        t=50,  # top
        b=80,  # bottom  ← your problem
        l=50,  # left
        r=120,  # right
    ),
    plot_bgcolor='white',
    title='Quarterly Patient Waiting List Volume',
    xaxis_title='',
    yaxis_title='Patient Numbers',
    hovermode="x",
)

fig.update_yaxes(visible=False, secondary_y=True) #hides secondary axis
#fig.update_traces(mode="markers+lines", hovertemplate=None) #adds marks to line plots
fig.show()

# %% [markdown]
# The volume of patients treated have increased substantially from the quarterly collection point - however the net change of the waiting list is growing, not shrinking, and so output is not in step with capacity. The waiting list from June 2023 to June 2025 has steadily increased by 26.7%.

# %% [markdown]
# ## Gauge Flow Efficiency

# %% [markdown]
# _what to do next:_
# > calculate the ratio of treated to waiting patients per quarter and visualise.
#
# _why?_
# > By measuring this ratio, we can determine the capacity attending to general patients per quarter (number of quarters til fulfilment). General appointments have a desired wait of 24months maximum, we can cross examine quarterly capacity in months against desired wait time. This will inform us on the systems adherence to desired treatment times. 24 months+ worth of volume exceeds the waitlist threshold.

# %% [markdown]
# **Calculated below**:
# - quarterly pct_treated vs waiting, where ratio = (treated/waiting)
# - finding total months to fulfil waitlist, months = (1/ratio)
# - define years and months to clear waitlist (per quarter) given rate of treatment.

# %%
import numpy as np
import pandas as pd

# compute capacity ratio
df_quarterly['capacity_ratio'] = (df_quarterly['total_treated'] / df_quarterly['total_waiting']).round(3)
df_quarterly['capacity_pct'] = (df_quarterly['capacity_ratio'] * 100).round(1)
df_quarterly['capacity_ratio'] = df_quarterly['capacity_ratio'].replace([np.inf, -np.inf], pd.NA)

# quarters to clear backlog (1 / ratio) — keep as float for now and let NaN propagate
df_quarterly['n_quarters_to_100_percent'] = (1 / df_quarterly['capacity_ratio']).replace([np.inf, -np.inf], pd.NA)

# convert quarters -> months, round to nearest month, then cast to nullable Int64
total_months = (df_quarterly['n_quarters_to_100_percent'] * 3).round()  # float with NaN allowed
df_quarterly['capacity_total_months'] = total_months.astype('Int64')   # nullable integer

# compute years and months as nullable integers
df_quarterly['capacity_years'] = (df_quarterly['capacity_total_months'] // 12).astype('Int64')
df_quarterly['capacity_months'] = (df_quarterly['capacity_total_months'] % 12).astype('Int64')

# optional: readable string column (leave numeric columns for analysis)
def format_years_months(v):
    if pd.isna(v):
        return pd.NA
    v = int(v)  # safe because we checked for NA
    yrs = v // 12
    mths = v % 12
    return f"{yrs} years and {mths} months"

df_quarterly['capacity_years_months'] = df_quarterly['capacity_total_months'].apply(format_years_months)

# peek
df_quarterly[['capacity_pct','capacity_total_months','capacity_years_months']].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 import pandas as pd
#       4 # compute capacity ratio
# ----> 5 df_quarterly['capacity_ratio'] = (df_quarterly['total_treated'] / df_quarterly['total_waiting']).round(3)
#       6 df_quarterly['capacity_pct'] = (df_quarterly['capacity_ratio'] * 100).round(1)
#       7 df_quarterly['capacity_ratio'] = df_quarterly['capacity_ratio'].replace([np.inf, -np.inf], pd.NA)
#
# NameError: name 'df_quarterly' is not defined

# %%
import plotly.express as px
colours = ['blue' if v < 24 else 'lightcoral' for v in df_quarterly['capacity_total_months']]

#bar plot
fig = px.bar(
    df_quarterly,
    x=df_quarterly.index,
    y='capacity_total_months',
    title='Months to Clear Waitlist at Current Quarterly Treatment Rate',
    labels={
        'capacity_total_months': 'Months',
        'quarter_start': 'Quarter Period',}
)

fig.update_traces(
    marker_color=colours,
    marker_opacity=0.6
)

#dashed line at 24 month threshold
fig.add_hline(
    y=24, 
    line_dash="dash", 
    line_color="salmon"
)
fig.add_annotation(
                   y=24,
                   yref='y',
                   xref='paper',
                   x=.8, # place annotation at 75% of x-axis
                   text="24 Month Threshold",
                   showarrow=False,
                   xanchor='left',
                   yanchor='bottom',
                   font=dict(size=12, color="lightcoral"))
#shade area above threshold
#fig.add_hrect(
#    y0=24, 
#    y1=df_quarterly['capacity_total_months'].max() * 1.1, 
#    fillcolor="lightcoral", 
#    opacity=0.2, 
#    layer="below", 
#    line_width=0
#)

#change background to white
fig.update_layout(plot_bgcolor='white')

fig.show()

# %%
import pandas as pd

# ensure index is datetime
df_quarterly.index = pd.to_datetime(df_quarterly.index)

q2_2023_waiting = df_quarterly.loc['2023-04-01', 'total_waiting'] 
q2_2023_treated = df_quarterly.loc['2023-04-01', 'total_treated']
q2_2025_waiting = df_quarterly.loc['2025-04-01', 'total_waiting']
q2_2025_treated = df_quarterly.loc['2025-04-01', 'total_treated']

## Metrics:

increase = q2_2025_waiting - q2_2023_waiting
                                    #the increase in patients waiting from Q2 2023 to Q2 2025
percent_increase = (increase / q2_2023_waiting) * 100  
                                    # percent_increase Q2 2023 to Q2 2025 = (increase/q2_2023\_waiting)*100
patient_ratio_2023 = q2_2023_treated / q2_2023_waiting
                                    #the ratio of treated to waiting patients in Q2 2023
patient_ratio_2025 = q2_2025_treated / q2_2025_waiting
                                    #the ratio of treated to waiting patients in Q2 2025
excess_waiting = increase/8 
                                    #the increase in patients / the number of quarters in 24 months (8)
                                    
print(f"Using the most recent and consistent data -  starting at quarterly collection rate.\nFrom Q2 2023 to Q2 2025, the waiting list increased by {increase} patients, which is a {percent_increase:.2f}% increase.")
print(f"In Q2 2023, the ratio of treated to waiting patients was {patient_ratio_2023:.4f} (or {patient_ratio_2023*100:.2f}%). To keep up with the increase in waiting list,\napproximately {excess_waiting:.0f} additional patients would need to be treated each quarter (assuming a 12-24 month wait time).")
# Out:
# Using the most recent and consistent data -  starting at quarterly collection rate.
# From Q2 2023 to Q2 2025, the waiting list increased by 35162 patients, which is a 26.85% increase.
# In Q2 2023, the ratio of treated to waiting patients was 0.0696 (or 6.96%). To keep up with the increase in waiting list,
# approximately 4395 additional patients would need to be treated each quarter (assuming a 12-24 month wait time).

# %% [markdown]
# #### How do capacity trends compare across visit types?
# A General type of appointment has a waitlist time of 12-24months(8 quarters).
# General is just one type of visit - the measures of wait time differs across various types of visits.
#
# ## What is the proportion of visit type volume across the waitlist?

# %%
df_avg_visit_pct_sorted = df_avg_visit_pct.sort_values(by='pct_of_list', ascending=False)

fig = px.bar(df_avg_visit_pct_sorted, text_auto=True, x='visit_type', y='pct_of_list',
             labels={'pct_of_list':'%', 'visit_type':''},
             )
fig.update_layout(
    showlegend=False,
    yaxis_visible=False
)
fig.update_traces(
    textfont_size=18,
    texttemplate='%{y:.1f}%'
)
fig.show()

priority3 = df_avg_visit_pct.query("visit_type == 'Priority 3'")['pct_of_list'].values[0]
priority2 = df_avg_visit_pct.query("visit_type == 'Priority 2'")['pct_of_list'].values[0]

# notation
print(f"Majority of dental visits are a General service, accounting for {general_pct:.2f}% of total waiting on average across quarters.\nFollowed by Priority 3 with {priority3:.2f}% and Priority 2 with {priority2:.2f}% of average patients waiting.")
# Out:
# Majority of dental visits are a General service, accounting for 88.16% of total waiting on average across quarters.
# Followed by Priority 3 with 6.37% and Priority 2 with 3.16% of average patients waiting.

# %% [markdown]
# ### Capacity ratios of catchments (General)

# %%
df_catchment_avg.head(10)
# Out:
#   quarter_start  clinic_id               clinic_name  clinic_waiting_total  \
# 0    2020-01-01         23    ATHERTON DENTAL CLINIC                  1084
# 1    2020-01-01        136  GEORGETOWN DENTAL CLINIC                     2
# 2    2020-01-01        135    YARRABAH DENTAL CLINIC                     1
# 3    2020-01-01         21     MOSSMAN DENTAL CLINIC                   553
# 4    2020-01-01         30    EDMONTON DENTAL CLINIC                  1484
# 5    2020-01-01         28       TULLY DENTAL CLINIC                   728
# 6    2020-01-01         27  SMITHFIELD DENTAL CLINIC                   975
# 7    2020-01-01         26  CAIRNS NTH DENTAL CLINIC                  2636
# 8    2020-01-01         25     MAREEBA DENTAL CLINIC                  1243
# 9    2020-01-01        133     CROYDON DENTAL CLINIC                     0
#
#    clinic_treated_total  catchment_total  pct_of_catchment  \
# 0                    28             9903         10.946178
# ...

# %%
recent_quarter = df_catchment_avg[df_catchment_avg['quarter_start'] == df_catchment_avg['quarter_start'].max()]

# %%
import numpy as np
recent_quarter['threshold'] = np.where(recent_quarter['total_months'] > 24, 'Over', 'Under')

fig = px.scatter(
    recent_quarter, 
    y='catchment',
    x='total_months',
    hover_data='clinic_name',
    size='pct_of_catchment',
    color='threshold',
    title='Q2 2025 Waitlist Treatment Rate per Clinic, Catchment',
    labels={
        'catchment': 'Catchment, clinics',
        'total_months': '(In Months)',}
)
fig.update_layout(
    scattergap=0.5
)
fig.show()
# Out:
# /var/folders/9p/v7338qy117dc5b0yygsq9ndw0000gp/T/ipykernel_26423/3385902409.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# slider (quarters)

import plotly.express as px
import plotly.graph_objects as go

fig = px.scatter(df_catchment_avg, 
                 y="total_months", 
                 x="catchment", 
                 color="total_months",
                 hover_data=['clinic_name'] #add clinic_name to tooltip
)
fig.update_traces(marker_size=10)
fig.update_layout(scattermode="group",
                  scattergap=0.75)

import plotly.graph_objects as go

quarters = sorted(df_catchment_avg['quarter_start'].unique())

# one trace per quarter, only first visible
traces = []
for q in quarters:
    df_q = df_catchment_avg[df_catchment_avg['quarter_start'] == q]
    traces.append(go.Scatter(
        x=df_q['total_months'],
        y=df_q['catchment'],
        mode='markers',
        name=str(q),
        visible=(q == quarters[0])
    ))

# build slider steps
steps = []
for i, q in enumerate(quarters):
    step = dict(
        method='update',
        label=str(q),
        args=[{'visible': [j == i for j in range(len(quarters))]}]
    )
    steps.append(step)

fig = go.Figure(traces)

fig.update_layout(
    sliders=[dict(steps=steps, currentvalue={"prefix": "Quarter: "})]
)

fig.show()

# %% [markdown]
# capacity_pct legend:
# 0.00% — no one treated regardless of queue (Croydon 1,0 case)
# low % — high pressure, slow clearance (Innisfail at 0.30%)
# high % — healthy throughput relative to queue
# 800% — queue is negligible relative to throughput (Yarrabah)
# NULL — no one waiting, queue cleared, clinic not under pressure
#
# Thoughts:
# Reminder of the limitations and definitions of the data -
# -    *Waiting Patients* are a snap shot of the wait list volume at the end of each quarter
# -    *Treated Patients* are the flow of patients treated in the duration of the quarter.

# %% [markdown]
# method note:
# clinics at 0% are valid observations not to be excluded - they represent the most under-active clinics in terms of capacity and are crucial to stopping the trends of stress within the system.

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd

# ─── 0. RESET — makes cell safe to re-run ────────────────────────────────────
# Clears any existing figure and callbacks from a previous run
try:
    fig.data = []        # clears all traces
    fig.layout = {}
    for trace in fig.data:   # iterates over an already empty list — does nothing
        trace._hover_callbacks = []
        trace._unhover_callbacks = []
except Exception:
    pass

# ─── 1. PREP ──────────────────────────────────────────────────────────────────
df = df_catchment_avg.copy()  # own the dataframe, fixes SettingWithCopyWarning

rng = np.random.default_rng(seed=42)
df['jitter_x'] = rng.uniform(-0.15, 0.15, size=len(df))

df['opacity'] = 0.15 + 0.85 * (
    df['clinic_waiting_total'] / df['clinic_waiting_total'].max()
).fillna(0.15)

df['log_capacity'] = np.where(
    df['capacity_pct'] > 0,
    np.log10(df['capacity_pct']),
    None  # None serialises as JSON null — fixes NaN warnings
)

df['quarter_label'] = pd.PeriodIndex(
    pd.to_datetime(df['quarter_start']), freq='Q'
).strftime('Q%q/%Y')

quarters    = sorted(df['quarter_start'].unique())
quarter_map = {q: i for i, q in enumerate(quarters)}
label_map   = dict(zip(df['quarter_start'], df['quarter_label']))

df['quarter_num']      = df['quarter_start'].map(quarter_map)
df['quarter_jittered'] = df['quarter_num'] + df['jitter_x']

# ─── 2. YEAR GROUPS ───────────────────────────────────────────────────────────
year_groups = {}
for q, i in quarter_map.items():
    year = str(q)[:4]
    year_groups.setdefault(year, []).append(i)

years_sorted = sorted(year_groups.keys())
n = len(years_sorted)
year_colors = {
    year: f'rgba(70, 130, 220, {0.04 + 0.08 * i / max(n - 1, 1):.2f})'
    for i, year in enumerate(years_sorted)
}

# ─── 3. SHAPES AND ANNOTATIONS ───────────────────────────────────────────────
shapes      = []
annotations = []

for year, indices in year_groups.items():
    x0 = min(indices) - 0.5
    x1 = max(indices) + 0.5

    shapes.append(dict(
        type='rect',
        x0=x0, x1=x1,
        y0=0, y1=1,
        xref='x', yref='paper',
        fillcolor=year_colors[year],
        line=dict(width=0),
        layer='below'
    ))

    annotations.append(dict(
        x=(x0 + x1) / 2,
        y=0.90,
        xref='x', yref='paper',
        text=f'<b>{year}</b>',
        showarrow=False,
        font=dict(size=28, color='rgba(0,0,0,0.06)'),
        xanchor='center',
        yanchor='bottom'
    ))

annotations.append(dict(
    x=0.75,
    y=2.15,
    xref='paper', yref='y',
    text='Breakeven (100%)',
    showarrow=False,
    font=dict(size=11, color='#0E51A8'),
    xanchor='right'
))

# ─── 4. CONSTANTS ─────────────────────────────────────────────────────────────
BASE_COLOR    = '#5B8FA8'
HIGHLIGHT     = '#FF7050'
FADED_OPACITY = 0.04

catchments = sorted(df['catchment'].unique())

# ─── 5. BUILD FIGURE ──────────────────────────────────────────────────────────
fig = go.FigureWidget()  # fresh instance every run

for catchment in catchments:
    group = df[df['catchment'] == catchment].copy()
    fig.add_trace(go.Scatter(
        x=group['quarter_jittered'],
        y=group['log_capacity'],
        mode='markers',
        name=catchment,
        marker=dict(
            size=8,
            color=BASE_COLOR,
            opacity=group['opacity'].tolist(),
            line=dict(width=0)
        ),
        customdata=group[[
            'clinic_name',
            'quarter_label',
            'clinic_waiting_total',
            'clinic_treated_total',
            'capacity_pct',
            'catchment'
        ]].values,  # .values ensures consistent indexing — no surprises from df index
        hovertemplate='<extra></extra>'
    ))

fig.add_hline(
    y=2,
    line_dash='dash',
    line_color='#0E51A8',
    line_width=1
)

# ─── 6. LAYOUT ────────────────────────────────────────────────────────────────
fig.update_layout(
    title='Clinic Capacity Distribution by Quarter',
    shapes=shapes,
    annotations=annotations,
    xaxis=dict(
        title='',
        tickvals=list(quarter_map.values()),
        ticktext=[label_map[q].split('/')[0] for q in quarters],
        showgrid=False,
        domain=[0, 0.78]
    ),
    yaxis=dict(
        title='Capacity % (log scale)',
        tickvals=[-1, 0, 1, 2, 3],
        ticktext=['0.1%', '1%', '10%', '100%', '1000%'],
        range=[-1.5, 3.5],
        showgrid=True,
        gridcolor='rgba(0,0,0,0.06)'
    ),
    plot_bgcolor='white',
    height=600,
    margin=dict(b=120, r=40),
    legend=dict(
        orientation='h',
        yanchor='top',
        y=-0.15,
        xanchor='center',
        x=0.5,
        font=dict(size=10, color='#888888'),
        itemsizing='constant',
        bgcolor='rgba(0,0,0,0)',
    ),
    hovermode='closest',
    legend_itemclick=False,
    legend_itemdoubleclick=False,
)

# ─── 7. HOVER PANEL ANNOTATION ────────────────────────────────────────────────
fig.add_annotation(
    x=0.80,
    y=1.0,
    xref='paper',
    yref='paper',
    text='<b>Hover over a point</b><br><br>Select a clinic',
    showarrow=False,
    align='left',
    xanchor='left',
    yanchor='top',
    bgcolor='rgba(255,255,255,0.95)',
    bordercolor='#dddddd',
    borderwidth=0,
    font=dict(size=12, color='#888888'),
    width=220,
)

PANEL_INDEX = len(fig.layout.annotations) - 1  # always points to the panel

# ─── 8. CALLBACKS ─────────────────────────────────────────────────────────────
# Defined after fig is built — only registered once per run

def clean(name):
    return name.replace('<span style="color:#0E51A8">', '').replace('</span>', '')

def on_hover(trace, points, state):
    if not points.point_inds:
        return
    i = points.point_inds[0]
    d = trace.customdata[i]
    hovered = clean(trace.name)

    with fig.batch_update():
        fig.layout.annotations[PANEL_INDEX].text = (
            f"<b>{d[0]}</b><br><br>"
            f"Quarter: {d[1]}<br>"
            f"Waiting: {int(d[2])}<br>"
            f"Treated: {int(d[3])}<br>"
            f"Capacity: {d[4]:.1f}%"
        )
        for t in fig.data:
            if not hasattr(t, 'marker'):
                continue
            t_name = clean(t.name)
            if t_name == hovered:
                t.marker.color   = HIGHLIGHT
                t.marker.opacity = df[df['catchment'] == hovered]['opacity'].tolist()
            else:
                t.marker.color   = BASE_COLOR
                t.marker.opacity = [FADED_OPACITY] * len(t.x)

def on_unhover(trace, points, state):
    with fig.batch_update():
        fig.layout.annotations[PANEL_INDEX].text = (
            '<b>Hover over a point</b><br><br>Select a clinic'
        )
        for t in fig.data:
            if not hasattr(t, 'marker'):
                continue
            t_name = clean(t.name)
            t.marker.color   = BASE_COLOR
            t.marker.opacity = df[df['catchment'] == t_name]['opacity'].tolist()

# Register callbacks once on the freshly built traces
for trace in fig.data:
    trace.on_hover(on_hover)
    trace.on_unhover(on_unhover)

# ─── 9. DISPLAY ───────────────────────────────────────────────────────────────
fig
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning:
#
# divide by zero encountered in log10
#
# /opt/anaconda3/lib/python3.13/site-packages/jupyter_client/session.py:721: UserWarning:
#
# Message serialization failed with:
# Out of range float values are not JSON compliant: nan
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#
# /opt/anaconda3/lib/python3.13/site-packages/jupyter_client/session.py:721: UserWarning:
#
# Message serialization failed with:
# Out of range float values are not JSON compliant: nan
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#
# /opt/anaconda3/lib/python3.13/site-packages/jupyter_client/session.py:721: UserWarning:
#
# Message serialization failed with:
# Out of range float values are not JSON compliant: nan
# ...

# %%
import plotly.graph_objects as go
import plotly.io as pio
import numpy as np
import pandas as pd

# ─── 1. PREP ──────────────────────────────────────────────────────────────────
df = df_catchment_avg.copy()

rng = np.random.default_rng(seed=42)
df['jitter_x'] = rng.uniform(-0.15, 0.15, size=len(df))

df['opacity'] = 0.20 + 0.80 * (
    df['clinic_waiting_total'] / df['clinic_waiting_total'].max()
).fillna(0.20)

df['log_capacity'] = np.where(
    df['capacity_pct'] > 0,
    np.log10(df['capacity_pct']),
    None
)

df['quarter_label'] = pd.PeriodIndex(
    pd.to_datetime(df['quarter_start']), freq='Q'
).strftime('Q%q %Y')

quarters    = sorted(df['quarter_start'].unique())
quarter_map = {q: i for i, q in enumerate(quarters)}
label_map   = dict(zip(df['quarter_start'], df['quarter_label']))

df['quarter_num']      = df['quarter_start'].map(quarter_map)
df['quarter_jittered'] = df['quarter_num'] + df['jitter_x']

# ─── 2. YEAR GROUPS ───────────────────────────────────────────────────────────
year_groups = {}
for q, i in quarter_map.items():
    year = str(q)[:4]
    year_groups.setdefault(year, []).append(i)

years_sorted = sorted(year_groups.keys())
n = len(years_sorted)
year_colors = {
    year: f'rgba(70, 130, 220, {0.03 + 0.07 * i / max(n - 1, 1):.2f})'
    for i, year in enumerate(years_sorted)
}

# ─── 3. CATCHMENT COLOUR PALETTE ─────────────────────────────────────────────
# 16 muted, distinct colours — readable on white, not overwhelming
PALETTE = [
    '#4878CF', '#6ACC65', '#D65F5F', '#B47CC7', '#C4AD66',
    '#77BEDB', '#F7910A', '#3B9E8A', '#E8625A', '#8C8C8C',
    '#5D6ABF', '#A3C647', '#D4889A', '#60C3D4', '#C4773B',
    '#7B68EE'
]

catchments  = sorted(df['catchment'].unique())
color_map   = {c: PALETTE[i % len(PALETTE)] for i, c in enumerate(catchments)}

# ─── 4. SHAPES AND ANNOTATIONS ───────────────────────────────────────────────
shapes      = []
annotations = []

for year, indices in year_groups.items():
    x0 = min(indices) - 0.5
    x1 = max(indices) + 0.5

    shapes.append(dict(
        type='rect',
        x0=x0, x1=x1,
        y0=0, y1=1,
        xref='x', yref='paper',
        fillcolor=year_colors[year],
        line=dict(width=0),
        layer='below'
    ))

    annotations.append(dict(
        x=(x0 + x1) / 2,
        y=0.90,
        xref='x', yref='paper',
        text=f'<b>{year}</b>',
        showarrow=False,
        font=dict(size=28, color='rgba(0,0,0,0.06)'),
        xanchor='center',
        yanchor='bottom'
    ))

annotations.append(dict(
    x=1.0,
    y=2.05,
    xref='paper', yref='y',
    text='Breakeven (100%)',
    showarrow=False,
    font=dict(size=11, color='#0E51A8'),
    xanchor='right'
))

# ─── 5. BUILD FIGURE ──────────────────────────────────────────────────────────
fig = go.Figure()

for catchment in catchments:
    group  = df[df['catchment'] == catchment].copy()
    colour = color_map[catchment]

    # Convert per-row opacity into individual marker colours with alpha
    # Plotly scatter doesn't support per-marker opacity with a single color string,
    # so we encode opacity into rgba strings per point
    def to_rgba(hex_color, alpha):
        hex_color = hex_color.lstrip('#')
        r, g, b = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
        return f'rgba({r},{g},{b},{alpha:.2f})'

    marker_colors = [
        to_rgba(colour, row['opacity'])
        for _, row in group.iterrows()
    ]

    fig.add_trace(go.Scatter(
        x=group['quarter_jittered'],
        y=group['log_capacity'],
        mode='markers',
        name=catchment,
        legendgroup=catchment,
        marker=dict(
            size=8,
            color=marker_colors,
            line=dict(width=0)
        ),
        customdata=group[[
            'clinic_name',
            'quarter_label',
            'clinic_waiting_total',
            'clinic_treated_total',
            'capacity_pct',
            'catchment'
        ]].values,
        hovertemplate=(
            '<b>%{customdata[0]}</b><br>'
            'Catchment: %{customdata[5]}<br>'
            'Quarter: %{customdata[1]}<br>'
            'Waiting: %{customdata[2]:,.0f}<br>'
            'Treated: %{customdata[3]:,.0f}<br>'
            'Capacity: %{customdata[4]:.1f}%'
            '<extra></extra>'
        )
    ))

# Breakeven line at log10(100) = 2
fig.add_hline(
    y=2,
    line_dash='dash',
    line_color='#0E51A8',
    line_width=1
)

# ─── 6. LAYOUT ────────────────────────────────────────────────────────────────
fig.update_layout(
    title=dict(
        text='Clinic Capacity Distribution by Quarter',
        font=dict(size=15, color='#333333'),
        x=0.01
    ),
    shapes=shapes,
    annotations=annotations,
    xaxis=dict(
        title='',
        tickvals=list(quarter_map.values()),
        ticktext=[label_map[q].split('/')[0] if '/' in label_map[q]
                  else label_map[q].split(' ')[0] for q in quarters],
        showgrid=False,
    ),
    yaxis=dict(
        title='Capacity % (log scale)',
        tickvals=[-1, 0, 1, 2, 3],
        ticktext=['0.1%', '1%', '10%', '100%', '1000%'],
        range=[-1.5, 3.5],
        showgrid=True,
        gridcolor='rgba(0,0,0,0.06)'
    ),
    plot_bgcolor='white',
    paper_bgcolor='white',
    height=600,
    margin=dict(b=40, r=20, t=50, l=60),
    legend=dict(
        orientation='h',
        yanchor='top',
        y=-0.08,
        xanchor='center',
        x=0.5,
        font=dict(size=10, color='#888888'),
        itemsizing='constant',
        bgcolor='rgba(0,0,0,0)',
        # clicking legend item isolates that catchment
        # double-click restores all
    ),
    hovermode='closest',
)

# ─── 7. DISPLAY IN NOTEBOOK ───────────────────────────────────────────────────
fig.show()

# ─── 8. EXPORT TO HTML ────────────────────────────────────────────────────────
# Full self-contained HTML — works in browser, GitHub Pages, portfolio sites
# Set the path to wherever you want the file saved
OUTPUT_PATH = PROJECT_ROOT / 'docs' / 'clinic_capacity_beeswarm.html'

# Create the output directory if it doesn't exist yet
OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)

pio.write_html(
    fig,
    file=OUTPUT_PATH,
    full_html=True,          # self-contained, includes Plotly JS
    include_plotlyjs=True,   # embeds the JS — no CDN dependency
    auto_open=False          # set True to pop open in browser after export
)

print(f'Plot exported to: {OUTPUT_PATH}')
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Plot exported to: /Users/charmay/Portfolio/qld_public_dental_list/docs/clinic_capacity_beeswarm.html

# %%
df_catchment_avg[df_catchment_avg['capacity_pct'] > 100].sort_values('capacity_pct', ascending=False)[
    ['clinic_name', 'quarter_start', 'clinic_waiting_total', 
     'clinic_treated_total', 'capacity_pct']
]
# Out:
#                    clinic_name quarter_start  clinic_waiting_total  \
# 131     YARRABAH DENTAL CLINIC    2024-04-01                     1
# 152     YARRABAH DENTAL CLINIC    2024-10-01                     3
# 2       YARRABAH DENTAL CLINIC    2020-01-01                     1
# 35      YARRABAH DENTAL CLINIC    2021-01-01                     1
# 187   WOORABINDA DENTAL CLINIC    2020-07-01                     1
# 68      YARRABAH DENTAL CLINIC    2022-10-01                     1
# 839   AUGATHELLA DENTAL CLINIC    2021-04-01                     1
# 21      YARRABAH DENTAL CLINIC    2020-07-01                     2
# 521     CLERMONT DENTAL CLINIC    2023-07-01                    29
# 82      YARRABAH DENTAL CLINIC    2023-04-01                     2
# 1159    RICHMOND DENTAL CLINIC    2024-04-01                     3
# 539     CLERMONT DENTAL CLINIC    2024-04-01                    38
# 55      YARRABAH DENTAL CLINIC    2021-04-01                     3
# ...

# %% [markdown]
# #### Capacity : aggregate to catchment level
# Encompasses the NULL values from high performing clinics.

# %% [markdown]
# ## Pressure Sensitivity
